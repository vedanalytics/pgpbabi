# %%
import pandas as pd

# %%
raw_train = pd.read_csv('Train.csv')

# %%
raw_train.head().T
# Out:
#                         0          1           2          3         4
# Client Id           12001      12002       12003      12004     12005
# age                   NaN        NaN         NaN        NaN       NaN
# job                admin.     admin.  technician   services       NaN
# own.house               1          1           0          1         0
# dependents              2          3           0          4         0
# marital               NaN    married     married    married    single
# gender                  F          F           M          M         F
# work.exp               14         16          15         14        15
# education       secondary  secondary         NaN  secondary  tertiary
# default                no         no          no         no        no
# balance              2343         45        1270       2476         0
# housing               yes         no         yes        yes       yes
# ...

# %%
len(raw_train)
# Out:
# 17323

# %%
raw_train.T
# Out:
#                     0          1           2          3         4      \
# Client Id           12001      12002       12003      12004     12005
# age                   NaN        NaN         NaN        NaN       NaN
# job                admin.     admin.  technician   services       NaN
# own.house               1          1           0          1         0
# dependents              2          3           0          4         0
# marital               NaN    married     married    married    single
# gender                  F          F           M          M         F
# work.exp               14         16          15         14        15
# education       secondary  secondary         NaN  secondary  tertiary
# default                no         no          no         no        no
# balance              2343         45        1270       2476         0
# housing               yes         no         yes        yes       yes
# ...

# %%
len(raw_train)
# Out:
# 8311

# %%
raw_train['age']
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-59a2d3561830> in <module>()
# ----> 1 raw_train['age'].values['nan']
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
raw_train.dropna(inplace=True)
