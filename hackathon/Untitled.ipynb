# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display
from sklearn import metrics

# %%
import pandas as pd

# %%
train = pd.read_csv('Train dataset-1.csv')

# %%
train.describe()
# Out:
# //anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        Registration Number  Annual Turnover  Facebook Popularity Quotient  \
# count          3493.000000     3.493000e+03                   3394.000000
# mean          21747.000000     3.072571e+07                     77.938715
# std            1008.486572     2.165125e+07                      9.829169
# min           20001.000000     3.500000e+06                     43.000000
# 25%           20874.000000     1.800000e+07                           NaN
# 50%           21747.000000     3.000000e+07                           NaN
# 75%           22620.000000     3.700000e+07                           NaN
# max           23493.000000     4.000000e+08                     97.760000
#
#        Instagram Popularity Quotient   Fire Audit  Liquor License Obtained  \
# count                    3437.000000  3493.000000              3493.000000
# ...

# %%
train.pivot_table
# Out:
# <bound method pivot_table of       Registration Number  Annual Turnover              Cuisine        City  \
# 0                   20001         42000000         indian,irish   Bangalore
# 1                   20002         50000000         indian,irish      Indore
# 2                   20003         32500000      tibetan,italian     Chennai
# 3                   20004        110000000     turkish,nigerian     Gurgaon
# 4                   20005         20000000        irish,belgian     Manesar
# 5                   20006         30000000        tibetan,greek   Hyderabad
# 6                   20007         30000000         indian,irish    Banglore
# 7                   20008         40000000         indian,irish   Bangalore
# 8                   20009         60000000  chinese,salvadorian       Noida
# 9                   20010         23000000     algerian,belgian     Kolkata
# 10                  20011         60000000           welsh,thai   Bangalore
# ...
